# %% [markdown]
# ## **문제 3: 업무 시간 계산하기**
#
# **"다람쥐는 오늘 근무한 시간을 계산하고 싶다."**
#
# 1. `work_hours(start, end)`라는 함수를 만들어 매개변수 `start`(출근 시간)와 `end`(퇴근 시간)를 입력받아 근무 시간을 계산하세요.
#     - 근무 시간 = `end - start`
# 2. 반환된 근무 시간을 출력하세요.
#     - 출력 예시: **"오늘 근무한 시간은 [근무 시간]시간입니다."**

# %%
start = int(input("출근 시간"))
end = int(input("퇴근 시간"))

def work_hours(start, end): return int(end - start)

print(f"오늘 근무한 시간은 {work_hours(start, end)}시간입니다.")
# Out:
# 오늘 근무한 시간은 1시간입니다.

# %% [markdown]
# ## **문제 4: 점심 메뉴 추천**
#
# **"점심시간, 다람쥐는 팀원들에게 점심 메뉴를 추천해준다."**
#
# 1. `recommend_menu(*menus)`라는 함수를 만들어 여러 개의 점심 메뉴를 매개변수로 전달받으세요.
# 2. 랜덤하게 하나의 메뉴를 선택하고 반환하세요.
#     - 출력 예시: **"오늘의 점심 메뉴는 [선택된 메뉴]입니다!"**
#     - 힌트: `random.choice()`를 사용하면 랜덤 선택이 가능합니다.

# %%
import random

menu1 = ["라면", "닭도리탕", "짜장면", "국밥", "치킨"]

def recommend_menu(*menus): return random.choice(menus)

print(f"오늘의 점심 메뉴는 {recommend_menu(*menu1)}입니다!")
# Out:
# 오늘의 점심 메뉴는 짜장면입니다!

# %% [markdown]
# ## **문제 5: 오후 커피 마시기**
#
# **"오후에 졸린 다람쥐는 커피를 마시려고 한다."**
#
# 1. `coffee_time()`이라는 함수를 만들어 다음과 같은 문자열을 반환하세요.
#     - **"오후 3시입니다. 커피 한 잔 하세요!"**
# 2. 반환된 문자열을 출력하세요.

# %%
def coffee_time(): return str("오후 3시입니다. 커피 한 잔 하세요!")

print(coffee_time())
# Out:
# 오후 3시입니다. 커피 한 잔 하세요!

# %% [markdown]
# ## **문제 6: 업무 성과 분석하기**
#
# **"다람쥐는 오늘의 업무 성과를 보고해야 한다."**
#
# 1. `work_report(tasks_done)`이라는 함수를 만들어 오늘 처리한 업무 수를 매개변수로 받으세요.
# 2. 함수는 다음 두 값을 반환합니다.
#     - `tasks_done`: 처리한 업무 수
#     - `status`: 업무 성과 평가 (10개 이상: "우수", 5~9개: "보통", 4개 이하: "노력 필요")
# 3. 반환된 값을 사용해 다음 메시지를 출력하세요.
#     - **"오늘 처리한 업무는 [업무 수]개입니다. 성과 평가: [평가]"**

# %%
tasks_done = int(input("처리한 업무의 수"))


def work_report(tasks_done):
     
     if tasks_done >= 10:
          status = "우수"
     
     if tasks_done >= 5 and tasks_done <= 9:
          status = "보통"
     
     if tasks_done <= 4 and tasks_done >= 0:
          status = "노력 필요"

     return status

print(f"오늘 처리한 업무는 {tasks_done}개 입니다. 성과 평가: {work_report(tasks_done)}")
# Out:
# 오늘 처리한 업무는 2개 입니다. 성과 평가: 노력 필요

# %% [markdown]
# ## **문제 7: 월급 계산 및 세금 공제**
#
# **"다람쥐는 첫 월급을 계산하고 세금을 공제해야 한다."**
#
# 1. `calculate_salary(base_salary, bonus)`라는 함수를 만들어 기본 월급과 보너스를 매개변수로 받으세요.
# 2. 총 월급을 계산하고, 세금은 총 월급의 10%로 공제하세요.
# 3. 함수는 다음 두 값을 반환합니다.
#     - `net_salary`: 실수령액 (총 월급 - 세금)２
#     - `tax`: 세금 공제액
# 4. 반환된 값을 사용해 다음 메시지를 출력하세요.
#     - **"세전 월급: [총 월급]원, 세금: [세금]원, 실수령액: [실수령액]원"**

# %%
base_salary = int(input("세전 월급: "))
bonus = int(input("보너스: "))

def calculate_salary(base_salary, bonus):
    net_salary = (base_salary + bonus) - (base_salary + bonus) * 0.1
    tax = base_salary + bonus - net_salary
    return net_salary, tax

net_salary, tax = calculate_salary(base_salary, bonus)

print(f"세전 월급: {base_salary + bonus}원, 세금: {tax}원, 실수령액: {net_salary}원")
# Out:
# 세전 월급: 3원, 세금: 0.2999999999999998원, 실수령액: 2.7원

# %% [markdown]
# 문제 1
#
# 리스트에 있는 숫자들의 합을 구해 반환(return) 하는 함수 sum_list를 작성하시오.
#
# numbers = [3, 5, 7, 10]

# %%
numbers = [3, 5, 7, 10]



def sum_list(*sum_nums):
    total = 0
    for x in sum_nums:
        total = total + x
    
    return total

print(sum_list(*numbers))
# Out:
# 25

# %%
numbers = [3, 5, 7, 10]

sum(numbers)
# Out:
# 25

# %% [markdown]
# 문제 2
#
# 문자열 리스트가 있을 때, 각 문자열의 길이를 새 리스트로 반환하는 함수 lengths 를 작성하시오.
#
# words = ["apple", "kiwi", "banana"]

# %%
words = ["apple", "kiwi", "banana"]

def lengths(*lengths_words):
    x = []
    for i in words:
        x.append(len(i))

    return x

print(lengths(*words))
# Out:
# [5, 4, 6]

# %% [markdown]
# 다음 딕셔너리에서 점수가 80 이상인 학생만 리스트로 반환하는 함수 get_honor 를 작성하시오.
#
# scores = {"Anna": 90, "Ben": 75, "Chris": 88, "Daisy": 60}

# %%
scores = {"Anna": 90, "Ben": 75, "Chris": 88, "Daisy": 60}

def get_honor(score_stu):
    x = []   
    for i, j in score_stu.items():
        if j >= 80:
            x.append(i)

    return x

print(get_honor(scores))
# Out:
# ['Anna', 'Chris']

# %%
scores = {"Anna": 90, "Ben": 75, "Chris": 88, "Daisy": 60}

scores.values()
# Out:
# dict_values

# %% [markdown]
# 리스트의 숫자 중 짝수만 리스트로 만들어 반환하는 함수 get_even 을 작성하시오.
#
# nums = [4, 7, 2, 9, 6, 11]

# %%
nums = [4, 7, 2, 9, 6, 11]

def get_even(numbers):
    return [even for even in numbers if even % 2 == 0]

print(get_even(nums))
# Out:
# [4, 2, 6]

# %% [markdown]
# 🧠 💡 보너스 문제 (심화)
#
# 문자열을 입력받아, 문자열 안에 포함된 모음(a, e, i, o, u)의 개수를 세서 딕셔너리로 반환하는 함수 count_vowels 를 작성하시오.
#
# ✔️ 조건
#
# 대문자/소문자 모두 처리 (예: A, a 둘 다 포함)
#
# 결과는 딕셔너리로 반환
#
# "banana apple"

# %%
text = "banana apple"

def count_vowels(text):
    vowels = ["a", "e", "i" , "o", "u", "A", "E", "I", "O", "U"]
    return {x: text.count(x) for x in vowels} 

print(count_vowels(text))
# Out:
# {'a': 4, 'e': 1, 'i': 0, 'o': 0, 'u': 0, 'A': 0, 'E': 0, 'I': 0, 'O': 0, 'U': 0}
