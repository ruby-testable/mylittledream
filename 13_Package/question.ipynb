# %% [markdown]
# 문제 1

# %%
from team_management import managers, developers

print(managers.manager())
print(developers.developer())
# Out:
# 팀장: 다람쥐
# 개발자: 산골 다람쥐

# %% [markdown]
# 문제 2

# %%
from work_management import task_tracking, reporting

print(task_tracking.start_task("코드 리뷰"))
print(task_tracking.end_task("코드 리뷰"))
print(reporting.generate_report("코드 리뷰"))
# Out:
# 작업 '코드 리뷰' 시작됨.
# 작업 '코드 리뷰' 종료됨.
# '코드 리뷰' 작업 보고서 생성됨.

# %% [markdown]
# 문제 3

# %%
import datetime
import schedule_management.calendar as cal

print(cal.add_event("회의", datetime.date(2025, 11, 28)))
print(cal.remove_event("회의"))
# Out:
# 2025-11-28에 '회의' 일정이 추가되었습니다.
# '회의' 일정이 삭제되었습니다.

# %% [markdown]
# 문제 4

# %%
import numpy

numbers = [2346, 1858, 19122, 5858]

print(numpy.mean(numbers))
# Out:
# 7296.0

# %% [markdown]
# 문제 5 : 다 풀기 성공~
