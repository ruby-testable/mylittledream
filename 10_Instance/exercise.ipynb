# %% [markdown]
# 인스턴스란 클래스로 객체를 생성하면 메모리에 매번 서로 다른 주소를 가진 인스턴스가 할당된다.
#
# 인스턴스는 각각 독립적인 공간이 되며, 필드가 있을 경우 서로 다른 상태 값을 가진다

# %%
class Person:    
    national = 'korea'
    language = 'korean'
    
    def __init__(self, name, age):
        self.name = name
        self.age = age
    
    def greeting(self):
        return '안녕하세요'
    
    def information(self):
        return "I'm from " + self.national + " and I use " + self.language + ". My name is " + self.name + ". I'm " + str(self.age)
    
    def favorite(self, color):
        return "I love " + color

squirrel = Person('다람쥐', 900)
Gorilla = Person('고릴라', 20)

print(squirrel)
print(Gorilla)

print(squirrel.national)            # korea
print(squirrel.greeting())          # 안녕하세요
print(Gorilla.information())        # I'm from korea and I use korean. My name is 고릴라. I'm 20
print(Gorilla.favorite('black'))    # I love black
# Out:
# <__main__.Person object at 0x000001DB3A9630E0>
# <__main__.Person object at 0x000001DB3B0765D0>
# korea
# 안녕하세요
# I'm from korea and I use korean. My name is 고릴라. I'm 20
# I love black

# %%
class Character:    
    skills = []
    
    def __init__(self, nickname, type):
        self.nickname = nickname
        self.type = type
        
    def add_skill(self, skill):
        self.skills.append(skill)
    
    def show_skill(self):
        return self.type + ' ' + self.nickname + '님의 보유 스킬 ' + str(self.skills)

my_character = Character('산골짜기다람쥐', '전사')
your_character = Character('흑염룡의고릴라', '법사')
my_character.add_skill('곤봉 휘두르기')
your_character.add_skill('마법진 그려서 날려버리기')

print(my_character.show_skill())  

# skills 리스트가 인스턴스 속성이 아닌, 클래스 속성이므로 공유된다.
# Out:
# 전사 산골짜기다람쥐님의 보유 스킬 ['곤봉 휘두르기', '마법진 그려서 날려버리기']

# %%
class Character:        
    def __init__(self, nickname, type):
        self.nickname = nickname
        self.type = type
        self.skills = []
        
    def add_skill(self, skill):
        self.skills.append(skill)
    
    def show_skill(self):
        return self.type + ' ' + self.nickname + '님의 보유 스킬 ' + str(self.skills)

my_character = Character('산골짜기다람쥐', '전사')
your_character = Character('흑염룡의고릴라', '법사')
my_character.add_skill('곤봉 휘두르기')
your_character.add_skill('마법진 그려서 날려버리기')

print(my_character.show_skill())    

# 인스턴스 속성으로 변경되어 공유되지 않는다.
# Out:
# 전사 산골짜기다람쥐님의 보유 스킬 ['곤봉 휘두르기']

# %%
class Character:        
    nickname = '땅파먹는개미핥기'
    
    def __init__(self, nickname, type):
        self.nickname = nickname
        self.type = type

my_character = Character('산골짜기다람쥐', '전사')

print(my_character.nickname)   

# 클래스 속성보다 인스턴스 속성을 우선하는 것을 알 수 있다.
# Out:
# 산골짜기다람쥐
