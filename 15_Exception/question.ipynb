# %% [markdown]
# ### **문제 1: 모든 예외 처리**
#
# 다람쥐는 파일에서 데이터를 읽으려고 하지만, 파일이 없을 경우 프로그램이 중단되지 않도록 처리하고 싶습니다.
#
# 1. `data.txt` 파일을 읽으려고 시도하세요.
# 2. 파일이 없을 경우, `"파일이 존재하지 않습니다."`를 출력하세요.
# 3. 파일이 존재하면 파일 내용을 출력하세요.:

# %%
try:
    f = open("data.txt", "r", encoding = "utf-8")
    data = f.read()
    print(data)

except:
    print("파일이 없는 데스우.")
# Out:
# 파일이 없는 데스우.

# %% [markdown]
# ### **문제 2: 특정 예외 처리**
#
# 다람쥐는 사용자에게 나이를 입력받아 성인인지 확인하려고 합니다.
#
# 1. 사용자로부터 나이를 입력받아 정수로 변환하세요.
# 2. 입력값이 숫자가 아닐 경우, `"숫자를 입력해야 합니다."`를 출력하세요.
# 3. 숫자가 올바르게 입력되면 나이가 19 이상인지 확인하고, 19 이상이면 `"성인입니다."`, 그렇지 않으면 `"미성년자입니다."`를 출력하세요.

# %%
try:
    input_age = int(input("나이를 입력해 주세용(숫자만 입력): "))

except:
    print("숫자만 입력해야하는 데스우.")

else:
    if int(input_age) >= 19:
        print("삐빅 성인입니다.")

    elif int(input_age) >= 1:
        print("삐빅 미성년자입니다.")
# Out:
# 삐빅 성인입니다.

# %% [markdown]
# ### **문제 3: 특수 예외 상황과 오류 변수 사용**
#
# 다람쥐는 숫자 두 개를 입력받아 나누기를 수행하려고 합니다.
#
# 1. 사용자로부터 두 숫자를 입력받아 나누기를 수행하세요.
# 2. 첫 번째 숫자가 0으로 나누기를 시도하면 `"0으로 나눌 수 없습니다."`를 출력하세요.
# 3. 입력값이 숫자가 아니면 `"숫자를 입력해야 합니다."`를 출력하세요.
# 4. 오류 메시지를 출력할 때 발생한 오류 내용을 함께 출력하세요.

# %%
try:
    num1 = float(input("나누어질 숫자를 입력해주세요: "))
    num2 = float(input("나눌 숫자를 입력해주세요: "))
    print(num1 / num2)
    

except ZeroDivisionError as e:
    raise print("수학 다시 배우셈.", e)

except ValueError as e:
    raise print("숫자를 입력해다오...", e)
# Out:
# 숫자를 입력해다오... could not convert string to float: 'ㅇ'
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[22], line 2
#       1 try:
# ----> 2     num1 = float(input("나누어질 숫자를 입력해주세요: "))
#       3     num2 = float(input("나눌 숫자를 입력해주세요: "))
#
# ValueError: could not convert string to float: 'ㅇ'
#
# During handling of the above exception, another exception occurred:
#
# TypeError                                 Traceback (most recent call last)
# Cell In[22], line 11
#       8     raise print("수학 다시 배우셈.", e)
#      10 except ValueError as e:
# ---> 11     raise print("숫자를 입력해다오...", e)
#
# TypeError: exceptions must derive from BaseException

# %% [markdown]
# ### **문제 4: finally 블럭**
#
# 다람쥐는 프로그램 실행 후 파일 자원을 반드시 정리해야 합니다.
#
# 1. `log.txt` 파일을 읽으려고 시도하세요.
# 2. 파일을 여는 중 예외가 발생할 경우, `"파일을 열 수 없습니다."`를 출력하세요.
# 3. 예외 발생 여부와 상관없이 파일 자원을 정리하는 메시지 `"파일 자원 정리 완료"`를 출력하세요.

# %%
try:
    f = open("log.txt", "r", encoding = "utf-8")

except:
    print("파일을 열 수 없어용")

finally:
    print("파일 자원 정리 완료")
# Out:
# 파일을 열 수 없어용
# 파일 자원 정리 완료

# %% [markdown]
# ### **문제 5: try-else 블럭**
#
# 다람쥐는 사용자로부터 숫자를 입력받아 2로 나눈 결과를 출력하려고 합니다.
#
# 1. 사용자로부터 숫자를 입력받아 정수로 변환하세요.
# 2. 입력값이 숫자가 아닐 경우 `"숫자를 입력해야 합니다."`를 출력하세요.
# 3. 숫자가 올바르게 입력되면 입력값을 2로 나눈 결과를 출력하세요.

# %%
try:
    num = int(input("숫자를 입력하세요: "))
    
except:
    print("숫자를 입력해야하는데스....")

else:
    print(num / 2)
# Out:
# 1.0
